# %% [markdown]
# ## FUNCIONES Y ARCHIVOS

# %% [raw]
# Definición de una función: Para definir una función en Python, se utiliza la palabra clave def,
# seguida del nombre de la función y paréntesis que pueden contener argumentos (parámetros) de entrada.
#
#     def mi_funcion():
#         #código
#
# Argumentos (parámetros): Los argumentos son valores que se pasan a una función para que los utilice durante su ejecución.
#
#     def saludar(nombre):
#         global otravar
#         print("Hola, " + nombre)
#         return loquesea
#
# Llamada a una función: Para ejecutar una función, debes llamarla por su nombre seguido de paréntesis que pueden contener los valores de los argumentos que quieres pasar.
#
#     var1 = saludar("Juan")
#
# Ámbito de las variables: Las variables definidas dentro de una función son locales a esa función y no están disponibles fuera de ella, a menos que se devuelva un valor o se utilice un enfoque como la declaración "global" para hacerlas globales.
#
# Funciones incorporadas: Python tiene muchas funciones incorporadas que se pueden utilizar sin necesidad de definirlas previamente. Por ejemplo, print(), len(), input(), etc.
#
# Funciones de biblioteca estándar: Python también proporciona una amplia variedad de módulos y bibliotecas que contienen funciones que pueden ser importadas y utilizadas en tu programa. Ejemplos incluyen el módulo math para operaciones matemáticas avanzadas o random para generar números aleatorios.
#
# Documentación de funciones: Es una buena práctica incluir docstrings en tus funciones para documentar su funcionamiento. Esto facilita la comprensión de cómo usar la función y qué hace.
#
#     def suma(a, b):
#         """
#         Esta función suma dos números y devuelve el resultado.
#         :param a: Primer número
#         :param b: Segundo número
#         :return: Suma de a y b
#         """
#         resultado = a + b
#         return resultado
#
# Funciones anidadas: Puedes definir funciones dentro de otras funciones. Estas funciones anidadas solo son visibles dentro de la función que las contiene.
#
# Funciones lambda: Las funciones lambda, también conocidas como funciones anónimas, son funciones pequeñas y anónimas definidas utilizando la palabra clave lambda.
#
#
#     cuadrado = lambda x: x ** 2

# %% [raw]
# 1. Codifica un programa “Loterías” que conteña un menú que acceda as seguintes funcións:
#
#     A. Un xerador de apostas da primitiva (6 números entre 1 e 49 máis o complementario entre 1 e o 9).
#     B. Xerador de Euromillóns (5 números entre 1 e 50 máis dous números “estrela” entre 1 e 9).
#     C. Un xerador de apostas da quiniela de fútbol, 15 resultados entre 1,X,2.
#     D. Un xerador de Lotería nacional. Un número entre o 00000 e o 99999.
#
# Valorarase que o menú sexa outra función.1

# %% [markdown]
# <img>![if_elif_else.png](attachment:63b57ed4-354a-43eb-913d-7441c49d37ec.png)
# </img>

# %% [markdown]
# ## Archivos

# %% [raw]
# Apertura de archivos:
#
#     A. Abrir un archivo en Python, se utiliza la función open(). Esta función toma al menos dos argumentos: el nombre del archivo y el modo de apertura.
#
#     Los modos de apertura más comunes son:
#         'r': Modo de lectura (por defecto). Abre el archivo para lectura.
#         'w': Modo de escritura. Abre el archivo para escritura, borrando su contenido existente o creando uno nuevo si el archivo no existe.
#         'a': Modo de anexar. Abre el archivo para escritura, pero no borra el contenido existente; en su lugar, agrega nuevos datos al final del archivo.
#         'b': Modo binario. Abre el archivo en modo binario (por ejemplo, 'rb' para lectura binaria).
#         'x': Modo exclusivo. Crea un archivo nuevo y falla si el archivo ya existe.
#
#
#                     archivo = open("miarchivo.txt", "r")
#
#     B. Para leer el contenido de un archivo, puedes usar el método read() en el objeto de archivo que se creó previamente. También puedes usar métodos como    readline() para leer una línea a la vez. Es importante cerrar el archivo después de leerlo utilizando el método close() para liberar recursos.1
#
#                 archivo = open("miarchivo.txt", "r")
#                 contenido = archivo.read()
#                 archivo.close()
#
#     C. Escritura en archivos se puedes usar el modo de apertura 'w' o 'a', dependiendo de si deseas sobrescribir el contenido existente o agregar nuevo contenido al final del archivo.
#
#     Utiliza el método write() para agregar texto al archivo
#
#             file = "datos.txt"
#             archivo = open(file, "w")
#             archivo.write("Este es un ejemplo de escritura en un archivo.")
#             archivo.close()
#
#
#     D. Manejo con 'with'. El uso del contexto with es una práctica recomendada ya que garantiza que el archivo se cierre automáticamente una vez que se sale del bloque with. No es necesario llamar a close() explícitamente
#
#             file = input("Nombre del fichero: ")
#             with open(file, "r") as archivo:
#                 contenido = archivo.read()
#             # El archivo se cierra automáticamente al salir del bloque "with"
#
#
#     E. Lectura y escritura de archivos binarios utilizando los modos 'rb' y 'wb'.
#
#             with open("imagen.jpg", "rb") as archivo_binario:
#                 datos = archivo_binario.read()
#
#             with open("copia_imagen.jpg", "wb") as copia_binaria:
#                 copia_binaria.write(datos)
#
#
#     F. Manejo de excepciones en archivos Python
#
#             Es importante manejar las excepciones relacionadas con la lectura y escritura de archivos, como FileNotFoundError y PermissionError, para evitar que el programa falle inesperadamente.
#
#                 try:
#                     # Intenta abrir el archivo para lectura
#                     with open("archivo.txt", "r") as archivo:
#                         contenido = archivo.read()
#                 except FileNotFoundError:
#                     print("El archivo no se encontró.")
#                 except IOError:
#                     print("Error de lectura/escritura en el archivo.")
#                 except Exception as e:
#                     print("Se produjo una excepción inesperada genérica del tipo que sea:", str(e))
#                 else:
#                     # Este bloque se ejecuta si no se produjo ninguna excepción
#                     print("Lectura exitosa.")
#                 finally:
#                     # Este bloque se ejecuta siempre, ocurra o no una excepción
#                     print("Cerrando el archivo (si está abierto).")

# %%
numero = 555
numero = str(numero).zfill(5)
print(numero)
# Out:
# 00555
